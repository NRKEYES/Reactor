# %%
# %matplotlib inline

from Reaction import Reaction

#functional = ["M06"]
#basisSet = ["6-31++G**"]

functional = ["CCSD(T)-F12/RI-CC"]
basisSet = ["Extrapolate(3)"]

#functional = ["B3LYP","M06","TPSS0"]
#basisSet = ["6-311G","6-31G","6-31+G*"]

#functional = ["B3LYP", "B2PLYP","M06","M06L","TPSS0","TPSSh","PBE0","D3BJ"]
#basisSet = ["6-311G","6-31G","6-31+G*","TZVPP","def2-TZVPD"]

myReaction = Reaction('CCSD')
myReaction.recover_calculations([functional,basisSet])
clean = myReaction.process_results()
clean
# Out:
# CCSD/5MnO+
# !!!!!!!!!!!!!!!!!!!!!!!! There was a parsing error.!!!!!!!!!!!!!!!!!!!!!!!!
# Filename: CCSD/5MnO+/CCSD(T)-f12Extrapolate(3)5MnO+.out
#                                   ID Job Status  Energy  Run Time Freq   RC
# Functional  Basis Set
# CCSD(T)-f12 Extrapolate(3)  36207186       None     NaN       NaN  NaN  NaN
# CCSD/H2
# !!!!!!!!!!!!!!!!!!!!!!!! There was a parsing error.!!!!!!!!!!!!!!!!!!!!!!!!
# Filename: CCSD/H2/CCSD(T)-f12Extrapolate(3)H2.out
#                                   ID Job Status  Energy  Run Time Freq   RC
# Functional  Basis Set
# CCSD(T)-f12 Extrapolate(3)  73780116       None     NaN       NaN  NaN  NaN
# CCSD/7MnO+
# !!!!!!!!!!!!!!!!!!!!!!!! There was a parsing error.!!!!!!!!!!!!!!!!!!!!!!!!
# Filename: CCSD/7MnO+/CCSD(T)-f12Extrapolate(3)7MnO+.out
#                                   ID Job Status  Energy  Run Time Freq   RC
# Functional  Basis Set
# CCSD(T)-f12 Extrapolate(3)  60949949       None     NaN       NaN  NaN  NaN
# CCSD/H2
# ...

# %%
myReaction.run_calculations([functional,basisSet])
# Out:
# Running Molecule: 5MnO+
# CCSD/5MnO+
# Rcovering any old molecular data...
# !!!!!!!!!!!!!!!!!!!!!!!! There was a parsing error.!!!!!!!!!!!!!!!!!!!!!!!!
# Filename: CCSD/5MnO+/CCSD(T)-f12Extrapolate(3)5MnO+.out
# Firing Calculation
# ---------------------------------------------------------------------------------
# --------------------------------Entering Submit cycle----------------------------
# ---------------------------------------------------------------------------------
# 0
#     Name: 5MnO+
#     Charge: 1
#     Multiplicity: 5
# ⚛    Mn  -0.004361      0.0      0.0
# ⚛    O   1.73446      0.0      0.0
# /1
# ('CCSD(T)-f12', 'Extrapolate(3)'):None
# /1/1!!!!!!!!!!!!!!!!!!!!!!!! There was a parsing error.!!!!!!!!!!!!!!!!!!!!!!!!
# Filename: CCSD/5MnO+/CCSD(T)-f12Extrapolate(3)5MnO+.out
# Total Time : 31.21030678600073
#                                   ID Job Status  Energy  Run Time Freq   RC
# Functional  Basis Set
# ...
